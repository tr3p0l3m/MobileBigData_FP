# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import folium
import geopandas as gpd
import rasterio
import glob
from pathlib import Path
from datetime import datetime
import networkx as nx
from shapely.geometry import Point, LineString
import matplotlib.patches as mpatches
import geopandas as gpd
from matplotlib.lines import Line2D
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from math import radians, sin, cos, sqrt, atan2
from sklearn.feature_selection import RFE
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression, LassoCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error, classification_report, jaccard_score, silhouette_score
from tabulate import tabulate
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %% [markdown]
# # Data Preparation and Understanding

# %% [markdown]
# ### Population dataset

# %%
# Load the population data into dataframes.
pop_df = pd.read_csv("GDL-Total-area-population-in-millions-data (1).csv")
pop_df.head()
# Out:
#   Country     Continent ISO_Code   Level  GDLCODE  \
# 0   India  Asia/Pacific      IND  Subnat  INDr136
# 1   India  Asia/Pacific      IND  Subnat  INDr101
# 2   India  Asia/Pacific      IND  Subnat  INDr125
# 3   India  Asia/Pacific      IND  Subnat  INDr102
# 4   India  Asia/Pacific      IND  Subnat  INDr103
#
#                         Region    2019    2020
# 0  Andaman and Nicobar Islands    0.37    0.36
# 1               Andhra Pradesh   52.00   51.10
# 2            Arunachal Pradesh    1.04    1.01
# 3                        Assam   34.80   35.90
# 4                        Bihar  125.00  127.00

# %%
# Get dataframe information.
pop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    36 non-null     object
#  1   Continent  36 non-null     object
#  2   ISO_Code   36 non-null     object
#  3   Level      36 non-null     object
#  4   GDLCODE    36 non-null     object
#  5   Region     36 non-null     object
#  6   2019       36 non-null     float64
#  7   2020       36 non-null     float64
# dtypes: float64(2), object(6)
# memory usage: 2.4+ KB

# %%
# Remove unneccessary columns.
columns_to_drop = ["Country", "Continent", "ISO_Code", "Level", "GDLCODE"]

pop_df.drop(columns = columns_to_drop, inplace = True)

# %%
# Check dataframe statistics
pop_df.describe()
# Out:
#              2019        2020
# count   36.000000   36.000000
# mean    37.939444   38.320556
# std     49.828100   50.954930
# min      0.070000    0.060000
# 25%      1.335000    1.280000
# 50%     23.850000   23.600000
# 75%     55.275000   54.750000
# max    231.000000  239.000000

# %% [markdown]
# - The population data for India in 2019 and 2020 shows a slight overall increase, with the mean rising from **37.94 million to 38.32 million**.
#
# - The high standard deviation (**49.83 in 2019 and 50.95 in 2020**) indicates significant variation across regions.
#
# - The median population remains relatively stable (**23.85 million in 2019 vs. 23.60 million in 2020**), suggesting that half of the regions have populations below this level.
#
# - The minimum population remains nearly unchanged, while the maximum increased from **231 million to 239 million**, reflecting growth in the most populous region.
#
# - The interquartile range remains similar, indicating that population distribution across regions has not changed drastically.

# %%
# Check for duplicates.
pop_df.duplicated().sum()
# Out:
# 0

# %%
# Check for null values.
pop_df.isna().sum()
# Out:
# Region    0
# 2019      0
# 2020      0
# dtype: int64

# %% [markdown]
# ### GDP data

# %%
# Load the GDP data into dataframes.
gdp_df = pd.read_csv("GDL-Log-Gross-National-Income-per-capita-in-1000-US-Dollars-(2011-PPP)-data (1).csv")
gdp_df.head()
# Out:
#   Country     Continent ISO_Code   Level  GDLCODE  \
# 0   India  Asia/Pacific      IND  Subnat  INDr136
# 1   India  Asia/Pacific      IND  Subnat  INDr101
# 2   India  Asia/Pacific      IND  Subnat  INDr125
# 3   India  Asia/Pacific      IND  Subnat  INDr102
# 4   India  Asia/Pacific      IND  Subnat  INDr103
#
#                         Region   2019   2020
# 0  Andaman and Nicobar Islands  9.272  9.195
# 1               Andhra Pradesh  8.967  8.892
# 2            Arunachal Pradesh  9.004  8.929
# 3                        Assam  8.331  8.262
# 4                        Bihar  8.198  8.130

# %%
# Check dataframe information.
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    36 non-null     object
#  1   Continent  36 non-null     object
#  2   ISO_Code   36 non-null     object
#  3   Level      36 non-null     object
#  4   GDLCODE    36 non-null     object
#  5   Region     36 non-null     object
#  6   2019       36 non-null     float64
#  7   2020       36 non-null     float64
# dtypes: float64(2), object(6)
# memory usage: 2.4+ KB

# %%
# Remove unneccessary columns.
columns_to_drop = ["Country", "Continent", "ISO_Code", "Level", "GDLCODE"]

gdp_df.drop(columns = columns_to_drop, inplace = True)

# %%
# Check dataframe statistics
gdp_df.describe()
# Out:
#             2019       2020
# count  36.000000  36.000000
# mean    8.964972   8.890056
# std     0.381007   0.377765
# min     8.198000   8.130000
# 25%     8.626000   8.554000
# 50%     9.036000   8.961000
# 75%     9.277250   9.200000
# max     9.579000   9.499000

# %% [markdown]
# - The GDP data for India in 2019 and 2020 shows a slight decline, with the mean decreasing from **8.96 to 8.89**.
#
# - The standard deviation remains relatively stable (**0.38 in 2019 vs. 0.38 in 2020**), indicating minimal variation across regions.
#
# - The median GDP also declined slightly (**9.04 in 2019 to 8.96 in 2020**), suggesting a general downward trend.
#
# - The maximum GDP dropped from **9.58 to 9.50**, while the minimum also decreased from **8.20 to 8.13**, reflecting a broad-based contraction.
#
# - The interquartile range (IQR) remains similar, indicating that the distribution of GDP values across regions has not changed significantly.

# %%
# Check for duplicates.
gdp_df.duplicated().sum()
# Out:
# 0

# %%
# Check for null values.
gdp_df.isna().sum()
# Out:
# Region    0
# 2019      0
# 2020      0
# dtype: int64

# %%
# Merge the datasets.
merged_df = pd.merge(gdp_df, pop_df, on="Region", how = "inner")
merged_df.head()
# Out:
#                         Region  2019_x  2020_x  2019_y  2020_y
# 0  Andaman and Nicobar Islands   9.272   9.195    0.37    0.36
# 1               Andhra Pradesh   8.967   8.892   52.00   51.10
# 2            Arunachal Pradesh   9.004   8.929    1.04    1.01
# 3                        Assam   8.331   8.262   34.80   35.90
# 4                        Bihar   8.198   8.130  125.00  127.00

# %%
# Melt GDP columns.
gdp_long = merged_df[["Region", "2019_x", "2020_x"]].melt(id_vars=["Region"], 
                                                          var_name="year", 
                                                          value_name="gdp")
gdp_long["year"] = gdp_long["year"].str.replace("_x", "").astype(int)

# Melt population columns.
pop_long = merged_df[["Region", "2019_y", "2020_y"]].melt(id_vars=["Region"], 
                                                          var_name="year", 
                                                          value_name="population")
pop_long["year"] = pop_long["year"].str.replace("_y", "").astype(int)

# Combine melted dataframes.
reshaped_df = pd.merge(gdp_long, pop_long, on=["Region", "year"], how="outer")

# Sort by Region and year.
reshaped_df = reshaped_df.sort_values(by=["Region", "year"]).reset_index(drop=True)
reshaped_df
# Out:
#                          Region  year    gdp  population
# 0   Andaman and Nicobar Islands  2019  9.272        0.37
# 1   Andaman and Nicobar Islands  2020  9.195        0.36
# 2                Andhra Pradesh  2019  8.967       52.00
# 3                Andhra Pradesh  2020  8.892       51.10
# 4             Arunachal Pradesh  2019  9.004        1.04
# ..                          ...   ...    ...         ...
# 67                Uttar Pradesh  2020  8.443      239.00
# 68                  Uttaranchal  2019  9.087       11.40
# 69                  Uttaranchal  2020  9.011       11.60
# 70                  West Bengal  2019  8.562      102.00
# 71                  West Bengal  2020  8.490      103.00
#
# [72 rows x 4 columns]

# %%
# Check dataframe information.
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Region  36 non-null     object
#  1   2019_x  36 non-null     float64
#  2   2020_x  36 non-null     float64
#  3   2019_y  36 non-null     float64
#  4   2020_y  36 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 1.5+ KB

# %% [markdown]
# ### Nighttime data.

# %%
# Load the truck data into dataframes.
nighttime_df = pd.read_csv("viirs_annual_pc11dist.csv")
nighttime_df.head()
# Out:
#    pc11_district_id  pc11_state_id  viirs_annual_min  viirs_annual_max  \
# 0               532             28          0.000000         47.335991
# 1               533             28          0.000000         39.871834
# 2               534             28          0.000000         55.269165
# 3               535             28          0.000000         47.633114
# 4               536             28         11.679568        110.478027
#
#    viirs_annual_mean  viirs_annual_sum  viirs_annual_num_cells       category  \
# 0           0.506407      40484.480053            79944.544753  median-masked
# 1           0.901833      35284.502309            39125.317318  median-masked
# 2           1.092501      63880.362758            58471.700079  median-masked
# 3           1.526908      72835.408423            47701.228541  median-masked
# 4          43.376884      49900.414293             1150.391864  median-masked
#
#    year
# 0  2021
# 1  2021
# 2  2021
# 3  2021
# 4  2021

# %%
# Check dataframe information.
nighttime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15360 entries, 0 to 15359
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   pc11_district_id        15360 non-null  int64
#  1   pc11_state_id           15360 non-null  int64
#  2   viirs_annual_min        15360 non-null  float64
#  3   viirs_annual_max        15360 non-null  float64
#  4   viirs_annual_mean       15360 non-null  float64
#  5   viirs_annual_sum        15360 non-null  float64
#  6   viirs_annual_num_cells  15360 non-null  float64
#  7   category                15360 non-null  object
#  8   year                    15360 non-null  int64
# dtypes: float64(5), int64(3), object(1)
# memory usage: 1.1+ MB

# %%
# Define state IDs and names.
state_id = list(range(1, 36))  
state_name = [
    "Jammu & Kashmir", "Himachal Pradesh", "Punjab", "Chandigarh", "Uttarakhand",
    "Haryana", "Delhi", "Rajasthan", "Uttar Pradesh", "Bihar", "Sikkim",
    "Arunachal Pradesh", "Nagaland", "Manipur", "Mizoram", "Tripura", "Meghalaya",
    "Assam", "West Bengal", "Jharkhand", "Odisha", "Chhattisgarh", "Madhya Pradesh",
    "Gujarat", "Daman & Diu", "Dadra & Nagar Haveli", "Maharashtra", "Andhra Pradesh",
    "Karnataka", "Goa", "Lakshadweep", "Kerala", "Tamil Nadu", "Puducherry",
    "Andaman & Nicobar"
]

# Create a dictionary mapping state IDs to state names.
state_dict = dict(zip(state_id, state_name))

# Map the state names to viirs_df based on state id.
nighttime_df["Region"] = nighttime_df["pc11_state_id"].map(state_dict)

# %%
# Filter for 2019-2020.
nighttime_df = nighttime_df[nighttime_df["year"].isin([2019, 2020])]

# %%
# Rename columns for clarity.
nighttime_df.rename(columns={
    "viirs_annual_mean": "viirs_mean",
    "viirs_annual_sum": "viirs_sum"
}, inplace=True)

# %%
# Aggregate to state level.
nighttime_state = nighttime_df.groupby(["pc11_state_id","Region","year"]).agg({
    "viirs_mean": "mean",  
    "viirs_sum": "sum"     
}).reset_index()


nighttime_state.head()
# Out:
#    pc11_state_id            Region  year  viirs_mean      viirs_sum
# 0              1   Jammu & Kashmir  2019    0.713755  260222.264499
# 1              1   Jammu & Kashmir  2020    0.776644  274668.174846
# 2              2  Himachal Pradesh  2019    0.255061   84888.714241
# 3              2  Himachal Pradesh  2020    0.242475   80605.107933
# 4              3            Punjab  2019    1.507757  794208.133853

# %%
# Remove the encoded state id.
nighttime_state.drop(columns="pc11_state_id", inplace=True)

# %%
# Check dataframe statistics.
nighttime_state[["viirs_mean", "viirs_sum"]].describe()
# Out:
#        viirs_mean     viirs_sum
# count   70.000000  7.000000e+01
# mean     2.767083  7.034839e+05
# std      6.236029  8.649581e+05
# min      0.036847  2.350699e+02
# 25%      0.497632  2.625249e+04
# 50%      0.745199  2.674452e+05
# 75%      2.252677  1.215996e+06
# max     33.491387  3.433784e+06

# %%
# Check for null values.
nighttime_state.isnull().sum()
# Out:
# Region        0
# year          0
# viirs_mean    0
# viirs_sum     0
# dtype: int64

# %%
# Merge the datasets.
combined_df = pd.merge(reshaped_df, nighttime_state, on=["Region", "year"], how="inner")
combined_df.head()
# Out:
#               Region  year    gdp  population  viirs_mean     viirs_sum
# 0     Andhra Pradesh  2019  8.967       52.00    2.754767  2.009531e+06
# 1     Andhra Pradesh  2020  8.892       51.10    2.718202  2.152512e+06
# 2  Arunachal Pradesh  2019  9.004        1.04    0.036847  2.432774e+04
# 3  Arunachal Pradesh  2020  8.929        1.01    0.042697  2.919143e+04
# 4              Assam  2019  8.331       34.80    0.490884  3.476018e+05

# %%
# Check dataframe information.
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Region      54 non-null     object
#  1   year        54 non-null     int32
#  2   gdp         54 non-null     float64
#  3   population  54 non-null     float64
#  4   viirs_mean  54 non-null     float64
#  5   viirs_sum   54 non-null     float64
# dtypes: float64(4), int32(1), object(1)
# memory usage: 2.4+ KB

# %%
# Convert year to datetime format.
# combined_df["year"] = pd.to_datetime(combined_df["year"].astype(str) + "-01-01")

# %%
# Check for duplicates.
combined_df.duplicated().sum()
# Out:
# 0

# %%
# Check for null values.
combined_df.isna().sum()
# Out:
# Region        0
# year          0
# gdp           0
# population    0
# viirs_mean    0
# viirs_sum     0
# dtype: int64

# %% [markdown]
# ### Truck delivery dataset

# %%
# Load the data into dataframes.
truck_df = pd.read_excel("archive/Delivery truck trip data.xlsx")
truck_df.head()
# Out:
#      GpsProvider           BookingID Market/Regular           BookingID_Date  \
# 0  CONSENT TRACK  MVCV0000927/082021          Market 2020-08-17 14:59:01.000
# 1        VAMOSYS  VCV00014271/082021         Regular 2020-08-27 16:22:22.827
# 2  CONSENT TRACK  VCV00014382/082021         Regular 2020-08-27 17:59:24.987
# 3        VAMOSYS  VCV00014743/082021         Regular 2020-08-28 00:48:24.503
# 4        VAMOSYS  VCV00014744/082021         Regular 2020-08-28 01:23:19.243
#
#    vehicle_no                                    Origin_Location  \
# 0    KA590408               TVSLSL-PUZHAL-HUB,CHENNAI,TAMIL NADU
# 1  TN30BC5917  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 2  TN22AR2748              LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
# 3  TN28AQ0781  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...
# 4   TN68F1722              LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY
#
#                                 Destination_Location      Org_lat_lon  \
# 0       ASHOK LEYLAND PLANT 1- HOSUR,HOSUR,KARNATAKA  13.1550,80.1960
# 1  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...  12.8390,79.9540
# 2              LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY  11.8710,79.7390
# 3  DAIMLER INDIA COMMERCIAL VEHICLES,KANCHIPURAM,...  12.8390,79.9540
# 4              LUCAS TVS LTD-PONDY,PONDY,PONDICHERRY  11.8720,79.6320
#
#        Des_lat_lon      Data_Ping_time  ... TRANSPORTATION_DISTANCE_IN_KM  \
# 0  12.7400,77.8200 2020-08-24 00:05:09  ...                         320.0
# 1  12.8390,79.9540 2020-08-28 12:40:28  ...                         103.0
# 2  11.8710,79.7390 2020-08-28 09:05:09  ...                         300.0
# 3  12.8390,79.9540 2020-08-28 12:40:31  ...                          61.0
# 4  11.8720,79.6320 2020-08-28 12:40:29  ...                         240.0
#
#   vehicleType Minimum_kms_to_be_covered_in_a_day Driver_Name  Driver_MobileNo  \
# 0         NaN                                NaN         NaN              NaN
# 1         NaN                                NaN      RAMESH              NaN
# 2         NaN                                NaN        GIRI              NaN
# 3         NaN                                NaN        RAVI              NaN
# 4         NaN                                NaN       TAMIL              NaN
#
#    customerID                          customerNameCode  supplierID  \
# 0  ALLEXCHE45                     Ashok leyland limited  VIJEXHOSR7
# 1  DMREXCHEUX  Daimler india commercial vehicles pvt lt  VJLEXSHE09
# 2  LUTGCCHE06                             Lucas tvs ltd  GSTEXLAK1Q
# 3  DMREXCHEUX  Daimler india commercial vehicles pvt lt  ARVEXNAM09
# 4  LUTGCCHE06                             Lucas tvs ltd  SRTEXKOR96
#
#     supplierNameCode          Material Shipped
# 0    VIJAY TRANSPORT     BRACKET / GRAB HANDLE
# 1       VJ LOGISTICS     ZB MODEL PLATE / 3143
# 2     G.S. TRANSPORT          LETTERING / FUSO
# 3  ARVINTH TRANSPORT  LU STRUT RA / RADIUS ROD
# 4      SR TRANSPORTS      WISHBONE / V ROD/HDT
#
# [5 rows x 32 columns]

# %%
# Get dataframe information.
truck_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6880 entries, 0 to 6879
# Data columns (total 32 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   GpsProvider                         5927 non-null   object
#  1   BookingID                           6880 non-null   object
#  2   Market/Regular                      6880 non-null   object
#  3   BookingID_Date                      6880 non-null   datetime64[ns]
#  4   vehicle_no                          6880 non-null   object
#  5   Origin_Location                     6880 non-null   object
#  6   Destination_Location                6880 non-null   object
#  7   Org_lat_lon                         6880 non-null   object
#  8   Des_lat_lon                         6880 non-null   object
#  9   Data_Ping_time                      5927 non-null   datetime64[ns]
#  10  Planned_ETA                         6880 non-null   object
#  11  Current_Location                    5916 non-null   object
#  12  DestinationLocation                 6880 non-null   object
#  13  actual_eta                          6843 non-null   object
#  14  Curr_lat                            5927 non-null   float64
#  15  Curr_lon                            5927 non-null   float64
#  16  ontime                              2548 non-null   object
#  17  delay                               4342 non-null   object
#  18  OriginLocation_Code                 6877 non-null   object
#  19  DestinationLocation_Code            6853 non-null   object
#  20  trip_start_date                     6880 non-null   object
#  21  trip_end_date                       6686 non-null   object
#  22  TRANSPORTATION_DISTANCE_IN_KM       6168 non-null   float64
#  23  vehicleType                         6052 non-null   object
#  24  Minimum_kms_to_be_covered_in_a_day  2820 non-null   float64
#  25  Driver_Name                         3451 non-null   object
#  26  Driver_MobileNo                     2691 non-null   float64
#  27  customerID                          6880 non-null   object
#  28  customerNameCode                    6880 non-null   object
#  29  supplierID                          6880 non-null   object
#  30  supplierNameCode                    6880 non-null   object
#  31  Material Shipped                    6880 non-null   object
# dtypes: datetime64[ns](2), float64(5), object(25)
# memory usage: 1.7+ MB

# %% [markdown]
# The dataframe consists of 32 columns and 6,880 rows, each representing information related to truck routes in India, such as location, material shipped, date, etc. It is apparent that some columns contain missing or null values, which may require further data cleaning or imputation to ensure accurate analysis and processing.

# %%
# Check the statistics.
truck_df.describe()
# Out:
#                       BookingID_Date                 Data_Ping_time  \
# count                           6880                           5927
# mean   2020-02-08 05:18:40.453054208  2020-04-06 04:54:24.370193920
# min              2019-03-18 12:19:22            2019-06-07 18:25:10
# 25%       2019-10-11 18:47:32.500000            2019-12-01 07:35:10
# 50%       2020-01-20 13:49:40.500000            2020-06-19 16:10:08
# 75%    2020-07-30 13:46:34.750000128            2020-08-10 15:52:45
# max              2020-12-03 13:10:21            2020-08-28 12:40:31
# std                              NaN                            NaN
#
#           Curr_lat     Curr_lon  TRANSPORTATION_DISTANCE_IN_KM  \
# count  5927.000000  5927.000000                    6168.000000
# mean     18.679995    78.759745                     553.856282
# min       8.166790    69.657698                       0.000000
# 25%      12.871868    76.891857                      40.000000
# 50%      17.470922    77.843340                     160.000000
# 75%      23.202009    80.018999                     900.000000
# max      32.367928    95.529550                    2954.700000
# std       6.075561     4.216357                     758.981836
#
#        Minimum_kms_to_be_covered_in_a_day  Driver_MobileNo
# count                         2820.000000     2.691000e+03
# mean                           250.239362     8.598981e+09
# min                              0.000000     6.000546e+09
# 25%                            250.000000     7.651505e+09
# 50%                            250.000000     8.930762e+09
# 75%                            250.000000     9.634981e+09
# max                            275.000000     1.000000e+10
# std                             24.315485     1.131669e+09

# %% [markdown]
#  Key statistics show a wide range of values:
#
#  - Transportation distances vary from 0 to 2954.7 km, with a mean of 553.86 km.
#
#  - The data spans from March 2019 to December 2020.
#
# Notably, some columns, such as "Driver_MobileNo," have null values, indicating missing data.
#
# The following columns are deemed unnecessary for the analysis and will be removed:
#
# 1. BookingID
# 2. Vehicle Number
# 3. Origin Location Code
# 4. Destination Location Code
# 5. Driver Mobile Number
# 6. Customer ID
# 7. Supplier ID
#
# These columns do not contribute to the analysis and will be dropped to streamline the dataset.

# %%
# Drop unnecessary columns.
columns_to_drop = ['BookingID', 'vehicle_no', 'OriginLocation_Code',
                   'DestinationLocation_Code',  'Driver_MobileNo',
                   'customerID', 'supplierID', 'vehicle_no', 'Driver_Name']

truck_df.drop(columns = columns_to_drop, inplace = True)

# %%
# Check for duplicates.
truck_df.duplicated().sum()
# Out:
# 6

# %%
# Drop duplicates.
truck_df.drop_duplicates(inplace = True)

# %%
# Check for null values.
missing_data = truck_df.isnull().sum()

# Plot missing data as a bar plot
plt.figure(figsize=(12, 6))
missing_data.plot(kind='bar', color='lightcoral')
plt.title('Missing Data Count')
plt.xlabel('Columns')
plt.ylabel('Missing Data Count')
plt.show()

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Plot distribution of the gdp,population and viirs data.
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
sns.histplot(combined_df['gdp'], bins=10, kde=True)
plt.title('GDP Distribution')
plt.subplot(1, 3, 2)
sns.histplot(combined_df['population'], bins=10, kde=True)
plt.title('Population Distribution')
plt.subplot(1, 3, 3)
sns.histplot(combined_df['viirs_mean'], bins=10, kde=True)
plt.title('VIIRS Mean Distribution')
plt.tight_layout()
plt.show()

# %% [markdown]
# - GDP shows a bimodal pattern (peaks at 8.5 and 9.25), indicating two economic clusters: less developed and more developed regions.
#
# - Population and VIIRS Mean are right-skewed, with most regions having small populations (0–25 million) and low nighttime light intensity (0–0.5), but a few outliers exhibit high values (up to 250 million and 3, respectively).
#
# - These patterns suggest economic activity and truck routes are concentrated in populous and urbanized regions, highlighting disparities that could inform targeted development policies.

# %%
plt.figure(figsize=(18, 6))

# GDP by Region
plt.subplot(1, 3, 1)
sns.barplot(x='Region', y='gdp', hue='year', data=combined_df)
plt.title('GDP by Region (2019 vs 2020)', fontsize=14)
plt.xlabel('Region', fontsize=12)
plt.ylabel('GDP', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.legend(title='Year')

# Population by Region
plt.subplot(1, 3, 2)
sns.barplot(x='Region', y='population', hue='year', data=combined_df)
plt.title('Population by Region (2019 vs 2020)', fontsize=14)
plt.xlabel('Region', fontsize=12)
plt.ylabel('Population (millions)', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.legend(title='Year')

# VIIRS Mean by Region
plt.subplot(1, 3, 3)
sns.barplot(x='Region', y='viirs_mean', hue='year', data=combined_df)
plt.title('VIIRS Mean by Region (2019 vs 2020)', fontsize=14)
plt.xlabel('Region', fontsize=12)
plt.ylabel('VIIRS Mean', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.legend(title='Year')

plt.tight_layout()
plt.show()

# %% [markdown]
# - GDP shows little change between years, with Maharashtra, Tamil Nadu, and Uttar Pradesh leading, while smaller regions like Sikkim and Lakshadweep have the lowest GDP.
#
# - Population remains stable, with Uttar Pradesh, Bihar, and Maharashtra having the largest populations (over 100 million), and smaller regions like Sikkim and Lakshadweep below 1 million.
#
# - VIIRS Mean, indicating economic activity, also shows minimal change, with Delhi, Chandigarh, and Goa having the highest values (around 2.5–3.0), while rural regions like Arunachal Pradesh and Nagaland have the lowest (below 0.5), highlighting persistent economic disparities.

# %%
corr_matrix = combined_df[['gdp', 'population', 'viirs_mean']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix - Economic Data')
plt.show()

# %% [markdown]
# - The correlation matrix for economic data in India shows the relationships between GDP, Population, and VIIRS Mean. GDP and Population have a moderate negative correlation (-0.38), indicating that higher GDP regions tend to have smaller populations, and vice versa.
#
# - Population and VIIRS Mean are moderately positively correlated (0.38), suggesting that more populous regions often have higher nighttime light intensity, reflecting greater economic activity.
#
# - GDP and VIIRS Mean have a weak positive correlation (0.14), implying a slight tendency for higher GDP regions to have higher economic activity, though the relationship is not strong.

# %%
plt.figure(figsize=(15, 5))

# GDP
plt.subplot(1, 3, 1)
sns.violinplot(x='year', y='gdp', hue='year', data=combined_df, palette='Set2', legend=False)
# plt.title('Violin Plot of GDP by Year', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('GDP', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

# Population
plt.subplot(1, 3, 2)
sns.violinplot(x='year', y='population', hue='year', data=combined_df, palette='Set2', legend=False)
# plt.title('Violin Plot of Population by Year', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Population (millions)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

# VIIRS Mean
plt.subplot(1, 3, 3)
sns.violinplot(x='year', y='viirs_mean', hue='year', data=combined_df, palette='Set2', legend=False)
# plt.title('Violin Plot of VIIRS Mean by Year', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('VIIRS Mean', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# - The violin plots compare GDP, Population, and VIIRS Mean across Indian regions for 2019 and 2020. GDP distributions are similar between years, ranging from 8.0 to 10.0 with a median around 9.0, showing no significant change.
#
# - Population distributions are also stable, ranging from 0 to 300 million with a median near 50 million, reflecting consistent population sizes.
#
# - VIIRS Mean distributions show a slight increase in 2020, ranging from 0 to 4 with a median around 0.5, indicating a minor rise in economic activity as measured by nighttime lights, though the overall spread remains wide.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(truck_df['TRANSPORTATION_DISTANCE_IN_KM'].dropna(), bins=30)
plt.title('Distribution of Transportation Distances')
plt.xlabel('Distance (km)')
plt.ylabel('Count')
plt.show()

# %%
# Check GPS service providers.
gps_provider_counts = truck_df['GpsProvider'].value_counts()

# Plot the top 10 providers.
top_10_gps_providers = gps_provider_counts[:10]

plt.figure(figsize=(12, 6))
plt.bar(top_10_gps_providers.index, top_10_gps_providers.values)
plt.xlabel('GPS Provider')
plt.ylabel('Frequency')
plt.title('Top 10 GPS Providers')
plt.xticks(rotation=90)
plt.show()

# %%
# Compute vehicle type counts.
vehicle_type_counts = truck_df['vehicleType'].value_counts()

# Plot the top 10 vehicle types.
top_10_vehicle_type = vehicle_type_counts[:10]

plt.figure(figsize=(12, 6))
plt.bar(top_10_vehicle_type.index, top_10_vehicle_type.values, color = "teal")
plt.xlabel('Vehicle Type')
plt.ylabel('Frequency')
plt.title('Top 10 Vehicle Types')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - **Heavy-Duty Vehicles (HCV & Trailers)** dominate transport, with **40 FT 3XL Trailer (35MT)** leading at **2,574 trips**. Other large vehicles like **40 FT Flat Bed Multi-Axle (27MT)** and **32 FT Multi-Axle (14MT)** are also heavily used.
#
# - **Medium Commercial Vehicles (MCV)** such as **19 FT Open (7MT)** and **22 FT Taurus Open (16MT)** are used for moderate loads.
#
# - **Small & Light Commercial Vehicles (LCV)** like **Tata 407 Open (2MT)** and **1.5 MT Pickup** cater to last-mile deliveries.
#
# - **Rare Vehicle Types**: Specialized or underutilized vehicles include **50 FT Flat Bed (30MT)** and **Mahindra LCV (1MT)**.

# %%
# Compute material counts.
material_counts = truck_df['Material Shipped'].value_counts()

# Plot the top 10 materials.
top_10_material = material_counts[:10]

plt.figure(figsize=(12, 6))
plt.bar(top_10_material.index, top_10_material.values, color = "brown")
plt.xlabel('Material')
plt.ylabel('Frequency')
plt.title('Top 10 Material Shipped')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - **Automotive Industry Dominance**: The majority of shipments relate to **auto parts**, with **1,510 entries**, followed by specific components like **GRS Starters (252)** and **M70 Starter Motors (215)**. This suggests a strong focus on vehicle manufacturing and maintenance.
#
# - **Reusable Packaging**: Items like **empty trays (172)** indicate logistics support, possibly for returnable packaging in supply chains.
#
# - **Niche & Low-Volume Items**: Some materials, such as **control lever assemblies and mounting brackets**, appear in very low quantities, likely serving specialized needs.

# %%
# Compute material counts.
market_counts = truck_df['Market/Regular '].value_counts()

# Plot the top 10 materials.
top_10_market = market_counts[:10]

# Plot the data
plt.figure(figsize=(10, 5))
sns.barplot(x=top_10_market.index, y=top_10_market.values, hue=top_10_market.index, palette="pastel", legend=False)
plt.xlabel('Trip Type')
plt.ylabel('Count')
plt.title('Type of Trip')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - Most of the trucks were categorized as "Regular," meaning they belonged to vendors with whom the company had an ongoing contract.
#
# - In contrast, "Market" trucks referred to vendors who operated without a formal contract, likely being engaged on an as-needed basis.

# %%
truck_df['Date'] = truck_df['Data_Ping_time'].dt.date
daily_trips = truck_df.groupby('Date').size()
plt.figure(figsize=(10, 6))
daily_trips.plot(kind='line')
plt.title('Daily Truck Trips')
plt.xlabel('Date')
plt.ylabel('Number of Trips')
plt.show()

# %% [markdown]
# - The line plot of daily truck trips from July 2019 to September 2020 shows significant fluctuations, with peaks reaching 120–140 trips and troughs near 0.
#
# - High activity occurs in July 2019, October 2019, and July–September 2020, while a sharp decline is observed from March to June 2020, likely due to COVID-19 lockdowns, with trips dropping to near zero in April 2020. Recovery begins in June 2020, with a notable increase in activity by July 2020, reflecting the resumption of economic operations.

# %%
# Group by month and year, then count bookings.
monthly_bookings = truck_df.groupby(truck_df['BookingID_Date'].dt.to_period('M')).size()

# Plot the time series.
plt.figure(figsize=(10, 6))
monthly_bookings.plot(kind='line', color='lightblue')
plt.title('Bookings Over Time')
plt.xlabel('Month')
plt.ylabel('Number of Bookings')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - There was a noticeable increase in bookings from May to September 2020, while the period from February to April 2020, as well as November to December 2020, showed a plateau.
#
# - From March 2019 onwards, booking trends fluctuated, with a significant spike observed between August and October 2019.

# %%
# Load India's map with state boundaries.
url = "https://raw.githubusercontent.com/geohacker/india/master/state/india_state.geojson"
india = gpd.read_file(url)

# Extract Origin and Destination Coordinates.
truck_df[['Origin_Lat', 'Origin_Lon']] = truck_df['Org_lat_lon'].str.split(',', expand=True).astype(float)
truck_df[['Dest_Lat', 'Dest_Lon']] = truck_df['Des_lat_lon'].str.split(',', expand=True).astype(float)

# Aggregate Routes to Reduce Clutter
# Create a new DataFrame to count the number of trips between each origin-destination pair
truck_df['Route'] = truck_df.apply(lambda row: (
    (row['Origin_Lon'], row['Origin_Lat']),
    (row['Dest_Lon'], row['Dest_Lat'])
), axis=1)
route_counts = truck_df.groupby('Route').size().reset_index(name='Trip_Count')

# Create a Directed Graph
G = nx.DiGraph()

# Add Nodes and Edges with Trip Counts
for _, row in route_counts.iterrows():
    origin, destination = row['Route']
    trip_count = row['Trip_Count']
    G.add_node(origin, pos=origin, type='origin')
    G.add_node(destination, pos=destination, type='destination')
    G.add_edge(origin, destination, weight=trip_count)

# Get node positions
pos = nx.get_node_attributes(G, 'pos')

# Separate nodes by type
origin_nodes = [node for node, data in G.nodes(data=True) if data['type'] == 'origin']
destination_nodes = [node for node, data in G.nodes(data=True) if data['type'] == 'destination']

# Plot the Map and Network Graph
fig, ax = plt.subplots(figsize=(12, 12))

# Plot India map with state boundaries
india.plot(ax=ax, color='lightgrey', edgecolor='black', alpha=0.8, linewidth=0.5)

# Add state labels (centroids of each state)
for idx, row in india.iterrows():
    centroid = row.geometry.centroid
    ax.annotate(
        row['NAME_1'],  # Correct column name for state names
        xy=(centroid.x, centroid.y),
        xytext=(0, 0),
        textcoords="offset points",
        fontsize=8,
        color='darkblue',
        ha='center',
        va='center'
    )

# Plot the network graph
# Draw edges (routes) with thickness based on trip count
edges = G.edges(data=True)
edge_weights = [data['weight'] for _, _, data in edges]  # Use trip count as edge weight
nx.draw_networkx_edges(G, pos, ax=ax, edge_color='grey', alpha=0.3, width=edge_weights, arrows=True, arrowstyle='->')

# Draw origin nodes 
nx.draw_networkx_nodes(G, pos, nodelist=origin_nodes, node_size=80, node_color='blue', ax=ax, alpha=0.7, node_shape='o')

# Draw destination nodes
nx.draw_networkx_nodes(G, pos, nodelist=destination_nodes, node_size=80, node_color='red', ax=ax, alpha=0.7, node_shape='^')

# Step 9: Customize the Plot
# Set title and labels with larger fonts
plt.title("Truck Route Network Over India", fontsize=16, pad=20)
plt.xlabel("Longitude", fontsize=12)
plt.ylabel("Latitude", fontsize=12)

# Add gridlines for better readability
ax.grid(True, linestyle='--', alpha=0.3)

# Add a Custom Legend
legend_elements = [
    Line2D([0], [0], marker='o', color='w', label='Origin', markerfacecolor='blue', markersize=10, alpha=0.7),
    Line2D([0], [0], marker='^', color='w', label='Destination', markerfacecolor='red', markersize=10, alpha=0.7),
    Line2D([0], [0], color='grey', lw=2, label='Route', alpha=0.3)
]
plt.legend(handles=legend_elements, loc='upper right', fontsize=10, title='Legend', title_fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# - The truck route network over India, shows dense activity in central and eastern states like Uttar Pradesh, Bihar, and West Bengal, with frequent routes (thick black lines) indicating high traffic, likely due to large populations and economic hubs.
#
# - Southern states like Tamil Nadu and Andhra Pradesh also exhibit notable activity, while northern and northeastern regions like Himachal Pradesh and Arunachal Pradesh have sparser routes.

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# #### Combine all data

# %%
truck_df['Origin_Location'] = truck_df['Origin_Location'].apply(lambda x:x.lower())
truck_df['Destination_Location'] = truck_df['Destination_Location'].apply(lambda x:x.lower())

# Extract the state from Origin_Location and Destination_Location.
truck_df['Origin_Region'] = truck_df['Origin_Location'].str.split(',').str[-1].str.strip()
truck_df['Destination_Region'] = truck_df['Destination_Location'].str.split(',').str[-1].str.strip()

# Standardize region names.
region_mapping = {
    "jammu & kashmir": "Jammu & Kashmir",
    "himachal pradesh": "Himachal Pradesh",
    "punjab": "Punjab",
    "chandigarh": "Chandigarh",
    "uttarakhand": "Uttarakhand",
    "haryana": "Haryana",
    "delhi": "Delhi",
    "rajasthan": "Rajasthan",
    "uttar pradesh": "Uttar Pradesh",
    "bihar": "Bihar",
    "sikkim": "Sikkim",
    "arunachal pradesh": "Arunachal Pradesh",
    "nagaland": "Nagaland",
    "manipur": "Manipur",
    "mizoram": "Mizoram",
    "tripura": "Tripura",
    "meghalaya": "Meghalaya",
    "assam": "Assam",
    "west bengal": "West Bengal",
    "jharkhand": "Jharkhand",
    "odisha": "Odisha",
    "chhattisgarh": "Chhattisgarh",
    "madhya pradesh": "Madhya Pradesh",
    "gujarat": "Gujarat",
    "daman & diu": "Daman & Diu",
    "dadra & nagar haveli": "Dadra & Nagar Haveli",
    "maharashtra": "Maharashtra",
    "andhra pradesh": "Andhra Pradesh",
    "karnataka": "Karnataka",
    "goa": "Goa",
    "lakshadweep": "Lakshadweep",
    "kerala": "Kerala",
    "tamil nadu": "Tamil Nadu",
    "puducherry": "Puducherry",
    "andaman & nicobar": "Andaman & Nicobar"
}


truck_df['Origin_Region'] = truck_df['Origin_Region'].map(region_mapping).fillna(truck_df['Origin_Region'])
truck_df['Destination_Region'] = truck_df['Destination_Region'].map(region_mapping).fillna(truck_df['Destination_Region'])

# Extract the year from Data_Ping_time.
truck_df['Year'] = truck_df['Data_Ping_time'].dt.year.astype('Int64')

# %%
# Check unmatched regions.
truck_regions = set(truck_df['Origin_Region'].unique())
combined_regions = set(combined_df['Region'].unique())

unmatched_regions = truck_regions - combined_regions
print("Unmatched regions:", unmatched_regions)
# Out:
# Unmatched regions: {'pondicherry', 'Delhi', 'india', 'chattisgarh', 'Odisha', 'telangana', 'Chandigarh'}

# %%
# Check unmatched years.
truck_years = set(truck_df['Year'].dropna().astype(int).unique())
combined_years = set(combined_df['year'].dropna().astype(int).unique())

unmatched_years = truck_years - combined_years
print("Unmatched years:", unmatched_years)
# Out:
# Unmatched years: set()

# %%
# Fix the unmatched regions.
region_fix_map = {
    'chattisgarh': 'Chhattisgarh',
    'pondicherry': 'Puducherry',
    'telangana': None,             # Not present in combined_df
    'india': None,                 # Not specific enough
    'Delhi': None,                 # Not present in combined_df
    'Chandigarh': 'Punjab',        # Closest match
    'Dadra & Nagar Haveli': 'Gujarat',    # Merge to nearby state
    'Jammu & Kashmir': None,       # Missing in combined_df
    'Uttarakhand': 'Uttar Pradesh',# Approximate for modeling
    'central development region': None    # Not a real state
}

# %%
# Map the regions to the truck dataframe.
truck_df['Origin_Region'] = truck_df['Origin_Region'].replace(region_fix_map)
truck_df['Destination_Region'] = truck_df['Destination_Region'].replace(region_fix_map)

# %%
# Remove rows where region is null.
truck_df = truck_df[truck_df['Origin_Region'].notna() & truck_df['Destination_Region'].notna()]

# %%
# Merge for Origin_Region
all_merged_df = truck_df.merge(
    combined_df,
    how='left',
    left_on=['Origin_Region', 'Year'],
    right_on=['Region', 'year'],
    suffixes=('', '_origin')
)

# Merge for Destination_Region
all_merged_df = all_merged_df.merge(
    combined_df,
    how='left',
    left_on=['Destination_Region', 'Year'],
    right_on=['Region', 'year'],
    suffixes=('_origin', '_destination')
)

# Drop redundant columns.
all_merged_df = all_merged_df.drop(columns=['Region_origin', 'year_origin', 'Region_destination', 'year_destination'])
all_merged_df.head()
# Out:
#      GpsProvider Market/Regular           BookingID_Date  \
# 0  CONSENT TRACK          Market 2020-08-17 14:59:01.000
# 1        VAMOSYS         Regular 2020-08-27 16:22:22.827
# 2  CONSENT TRACK         Regular 2020-08-27 17:59:24.987
# 3        VAMOSYS         Regular 2020-08-28 00:48:24.503
# 4        VAMOSYS         Regular 2020-08-28 01:23:19.243
#
#                                      Origin_Location  \
# 0               tvslsl-puzhal-hub,chennai,tamil nadu
# 1  daimler india commercial vehicles,kanchipuram,...
# 2              lucas tvs ltd-pondy,pondy,pondicherry
# 3  daimler india commercial vehicles,kanchipuram,...
# 4              lucas tvs ltd-pondy,pondy,pondicherry
#
#                                 Destination_Location      Org_lat_lon  \
# 0       ashok leyland plant 1- hosur,hosur,karnataka  13.1550,80.1960
# 1  daimler india commercial vehicles,kanchipuram,...  12.8390,79.9540
# 2              lucas tvs ltd-pondy,pondy,pondicherry  11.8710,79.7390
# 3  daimler india commercial vehicles,kanchipuram,...  12.8390,79.9540
# 4              lucas tvs ltd-pondy,pondy,pondicherry  11.8720,79.6320
#
#        Des_lat_lon      Data_Ping_time                 Planned_ETA  \
# 0  12.7400,77.8200 2020-08-24 00:05:09         2020-08-21 18:59:01
# 1  12.8390,79.9540 2020-08-28 12:40:28  2020-08-31 20:22:22.827000
# 2  11.8710,79.7390 2020-08-28 09:05:09  2020-08-31 21:59:24.987000
# 3  12.8390,79.9540 2020-08-28 12:40:31  2020-09-01 04:48:24.503000
# 4  11.8720,79.6320 2020-08-28 12:40:29  2020-09-01 05:23:19.243000
#
#                                     Current_Location  ... Destination_Region  \
# 0  Vaniyambadi Rd, Valayambattu, Tamil Nadu 63575...  ...          Karnataka
# 1  Unnamed Road, Oragadam Industrial Corridor, Va...  ...         Tamil Nadu
# 2  570, National Hwy 48, Shenoy Nagar, Chennai, T...  ...         Puducherry
# 3  Singaperumal Koil - Sriperumbudur Rd, Oragadam...  ...         Tamil Nadu
# 4            Melmaruvathur, Tamil Nadu 603319, India  ...         Puducherry
#
#    Year  gdp_origin  population_origin viirs_mean_origin viirs_sum_origin  \
# 0  2020       8.966              77.00          1.933853     1.392379e+06
# 1  2020       8.966              77.00          1.933853     1.392379e+06
# 2  2020       9.314               1.22          3.514007     2.078815e+04
# 3  2020       8.966              77.00          1.933853     1.392379e+06
# 4  2020       9.314               1.22          3.514007     2.078815e+04
#
#   gdp_destination population_destination  viirs_mean_destination  \
# 0           8.976                  71.70                1.398656
# 1           8.966                  77.00                1.933853
# 2           9.314                   1.22                3.514007
# 3           8.966                  77.00                1.933853
# 4           9.314                   1.22                3.514007
#
#   viirs_sum_destination
# 0          1.694715e+06
# 1          1.392379e+06
# 2          2.078815e+04
# 3          1.392379e+06
# 4          2.078815e+04
#
# [5 rows x 41 columns]

# %%
# Check dataframe information.
all_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5718 entries, 0 to 5717
# Data columns (total 41 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   GpsProvider                         5334 non-null   object
#  1   Market/Regular                      5718 non-null   object
#  2   BookingID_Date                      5718 non-null   datetime64[ns]
#  3   Origin_Location                     5718 non-null   object
#  4   Destination_Location                5718 non-null   object
#  5   Org_lat_lon                         5718 non-null   object
#  6   Des_lat_lon                         5718 non-null   object
#  7   Data_Ping_time                      5334 non-null   datetime64[ns]
#  8   Planned_ETA                         5718 non-null   object
#  9   Current_Location                    5323 non-null   object
#  10  DestinationLocation                 5718 non-null   object
#  11  actual_eta                          5682 non-null   object
#  12  Curr_lat                            5334 non-null   float64
#  13  Curr_lon                            5334 non-null   float64
#  14  ontime                              1954 non-null   object
#  15  delay                               3766 non-null   object
#  16  trip_start_date                     5718 non-null   object
#  17  trip_end_date                       5538 non-null   object
#  18  TRANSPORTATION_DISTANCE_IN_KM       5544 non-null   float64
#  19  vehicleType                         4890 non-null   object
#  20  Minimum_kms_to_be_covered_in_a_day  2192 non-null   float64
#  21  customerNameCode                    5718 non-null   object
#  22  supplierNameCode                    5718 non-null   object
#  23  Material Shipped                    5718 non-null   object
#  24  Date                                5334 non-null   object
#  25  Origin_Lat                          5718 non-null   float64
#  26  Origin_Lon                          5718 non-null   float64
#  27  Dest_Lat                            5718 non-null   float64
#  28  Dest_Lon                            5718 non-null   float64
#  29  Route                               5718 non-null   object
#  30  Origin_Region                       5718 non-null   object
#  31  Destination_Region                  5718 non-null   object
#  32  Year                                5334 non-null   Int64
#  33  gdp_origin                          5141 non-null   float64
#  34  population_origin                   5141 non-null   float64
#  35  viirs_mean_origin                   5141 non-null   float64
#  36  viirs_sum_origin                    5141 non-null   float64
#  37  gdp_destination                     5124 non-null   float64
#  38  population_destination              5124 non-null   float64
#  39  viirs_mean_destination              5124 non-null   float64
#  40  viirs_sum_destination               5124 non-null   float64
# dtypes: Int64(1), datetime64[ns](2), float64(16), object(22)
# memory usage: 1.8+ MB

# %%
# Load India's map with state boundaries.
url = "https://raw.githubusercontent.com/geohacker/india/master/state/india_state.geojson"
india = gpd.read_file(url)

# Aggregate nighttime intensity by state (Destination_Region)
state_intensity = all_merged_df.groupby('Destination_Region')['viirs_mean_destination'].mean().reset_index()

# Merge the aggregated data with the geospatial data
# Rename 'NAME_1' in GeoJSON to match 'Destination_Region' in DataFrame
india = india.rename(columns={'NAME_1': 'Destination_Region'})
merged = india.merge(state_intensity, on='Destination_Region', how='left')

# Plot the Map
fig, ax = plt.subplots(figsize=(12, 12))

# Plot India map with nighttime intensity
merged.plot(ax=ax, column='viirs_mean_destination', 
            cmap='YlOrRd',  # Yellow-Orange-Red colormap
            edgecolor='black', linewidth=0.5,
            legend=True,
            missing_kwds={'color': 'lightgrey', 'label': 'No Data'},
            legend_kwds={'label': "Nighttime Light Intensity (VIIRS Mean)",
                         'orientation': "vertical"})

# Add state labels (centroids of each state)
for idx, row in india.iterrows():
    centroid = row.geometry.centroid
    ax.annotate(
        row['Destination_Region'],
        xy=(centroid.x, centroid.y),
        xytext=(0, 0),
        textcoords="offset points",
        fontsize=8,
        color='darkblue',
        ha='center',
        va='center'
    )

# Plot origin points
ax.scatter(all_merged_df['Origin_Lon'], all_merged_df['Origin_Lat'], 
           s=80, c='blue', alpha=0.7, marker='o', label='Origin')

# Plot destination points
ax.scatter(all_merged_df['Dest_Lon'], all_merged_df['Dest_Lat'], 
           s=80, c='white', alpha=0.7, marker='^', label='Destination')

# Customize the Plot
plt.title("Nighttime Light Intensity by State with Origin-Destination Points", fontsize=16, pad=20)
plt.xlabel("Longitude", fontsize=12)
plt.ylabel("Latitude", fontsize=12)
ax.grid(True, linestyle='--', alpha=0.3)

# Add a Custom Legend
legend_elements = [
    Line2D([0], [0], marker='o', color='w', label='Origin', markerfacecolor='blue', markersize=10, alpha=0.7),
    Line2D([0], [0], marker='^', color='w', label='Destination', markerfacecolor='red', markersize=10, alpha=0.7)
]
plt.legend(handles=legend_elements, loc='upper right', fontsize=10, title='Points', title_fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# - The map illustrates nighttime light intensity variation across India using VIIRS Mean, with high intensity (2.5–3.0) in urbanized states like Delhi, Maharashtra, and Tamil Nadu (red), and low intensity (0.5) in rural states like Arunachal Pradesh and Nagaland (yellow).
#
# - Truck origins (blue circles) and destinations (red triangles) are concentrated in high-intensity states like Tamil Nadu and Andhra Pradesh, as well as populous states like Uttar Pradesh and Bihar, indicating that both economic activity and population drive truck activity, though northeastern states show sparse activity due to low light intensity and development.

# %%
# Step 1: Standardize case and strip whitespace in region columns
all_merged_df['Origin_Region'] = all_merged_df['Origin_Region'].str.strip().str.title()
all_merged_df['Destination_Region'] = all_merged_df['Destination_Region'].str.strip().str.title()

# Step 2: Prepare the state classification dictionary
state_area_classification = {
    'Andaman and Nicobar Islands': 'Urban',
    'Andhra Pradesh': 'Rural',
    'Arunachal Pradesh': 'Rural',
    'Assam': 'Rural',
    'Bihar': 'Rural',
    'Chandigarh': 'Urban',
    'Chhattisgarh': 'Rural',
    'Dadra and Nagar Haveli': 'Urban',
    'Delhi': 'Urban',
    'Goa': 'Urban',
    'Gujarat': 'Rural',
    'Haryana': 'Rural',
    'Himachal Pradesh': 'Rural',
    'Jammu and Kashmir': 'Rural',
    'Jharkhand': 'Rural',
    'Karnataka': 'Rural',
    'Kerala': 'Rural',
    'Ladakh': 'Rural',
    'Lakshadweep': 'Urban',
    'Madhya Pradesh': 'Rural',
    'Maharashtra': 'Urban',
    'Manipur': 'Rural',
    'Meghalaya': 'Rural',
    'Mizoram': 'Rural',
    'Nagaland': 'Rural',
    'Odisha': 'Rural',
    'Puducherry': 'Urban',
    'Punjab': 'Rural',
    'Rajasthan': 'Rural',
    'Sikkim': 'Rural',
    'Tamil Nadu': 'Rural',
    'Telangana': 'Urban',
    'Tripura': 'Rural',
    'Uttar Pradesh': 'Rural',
    'Uttarakhand': 'Rural',
    'West Bengal': 'Rural'
}

# Step 3: Map the classification to new columns
all_merged_df['Origin_Area'] = all_merged_df['Origin_Region'].map(state_area_classification)
all_merged_df['Destination_Area'] = all_merged_df['Destination_Region'].map(state_area_classification)

# Optional: Check for any regions that were not mapped
unmapped_origins = all_merged_df[all_merged_df['Origin_Area'].isnull()]['Origin_Region'].unique()
unmapped_destinations = all_merged_df[all_merged_df['Destination_Area'].isnull()]['Destination_Region'].unique()

print("Unmapped Origin Regions:", unmapped_origins)
print("Unmapped Destination Regions:", unmapped_destinations)
# Out:
# Unmapped Origin Regions: []
# Unmapped Destination Regions: []

# %%
# Number of Urban vs Rural after mapping
all_merged_df[['Origin_Area', 'Destination_Area']].apply(pd.Series.value_counts)
# Out:
#        Origin_Area  Destination_Area
# Rural         4893              5178
# Urban          825               540

# %%
# Drop rows with null values.
all_merged_df = all_merged_df.dropna(subset=['gdp_origin', 'gdp_destination'])
print(f"Remaining rows: {len(all_merged_df)}")
# Out:
# Remaining rows: 5116

# %% [markdown]
# ##### Handle Missing values

# %%
# Fill null values.

# Numerical columns.
numerical_cols_to_impute = ['TRANSPORTATION_DISTANCE_IN_KM']
for col in numerical_cols_to_impute:
    all_merged_df[col] = all_merged_df.groupby('Origin_Region')[col].transform(lambda x: x.fillna(x.median()))
    all_merged_df[col] = all_merged_df[col].fillna(all_merged_df[col].median())

all_merged_df['Minimum_kms_to_be_covered_in_a_day'] = all_merged_df['Minimum_kms_to_be_covered_in_a_day'].fillna(0)

# Categorical columns.
categorical_cols_to_impute = ['Current_Location', 'ontime', 'delay', 'vehicleType']
for col in categorical_cols_to_impute:
    all_merged_df[col] = all_merged_df[col].fillna('Unknown')

all_merged_df['actual_eta'] = all_merged_df['actual_eta'].fillna(all_merged_df['Planned_ETA'])
all_merged_df['trip_end_date'] = all_merged_df['trip_end_date'].fillna(all_merged_df['Planned_ETA'])

# %%
# Confirm no null values.
all_merged_df.isnull().sum()
# Out:
# GpsProvider                           0
# Market/Regular                        0
# BookingID_Date                        0
# Origin_Location                       0
# Destination_Location                  0
# Org_lat_lon                           0
# Des_lat_lon                           0
# Data_Ping_time                        0
# Planned_ETA                           0
# Current_Location                      0
# DestinationLocation                   0
# actual_eta                            0
# Curr_lat                              0
# Curr_lon                              0
# ontime                                0
# delay                                 0
# trip_start_date                       0
# trip_end_date                         0
# TRANSPORTATION_DISTANCE_IN_KM         0
# vehicleType                           0
# Minimum_kms_to_be_covered_in_a_day    0
# customerNameCode                      0
# supplierNameCode                      0
# Material Shipped                      0
# Date                                  0
# Origin_Lat                            0
# Origin_Lon                            0
# Dest_Lat                              0
# Dest_Lon                              0
# Route                                 0
# Origin_Region                         0
# Destination_Region                    0
# Year                                  0
# gdp_origin                            0
# population_origin                     0
# viirs_mean_origin                     0
# viirs_sum_origin                      0
# gdp_destination                       0
# population_destination                0
# viirs_mean_destination                0
# viirs_sum_destination                 0
# Origin_Area                           0
# Destination_Area                      0
# dtype: int64

# %% [markdown]
# #### Feature engineering

# %%
# Economic features
all_merged_df['viirs_per_capita_origin'] = all_merged_df['viirs_mean_origin'] / all_merged_df['population_origin'].replace(0, 1)
all_merged_df['gdp_ratio'] = all_merged_df['gdp_origin'] / all_merged_df['gdp_destination'].replace(0, 1)

# %%
# Spatial features: Haversine distance
def haversine(lat1, lon1, lat2, lon2):
    R = 6371  # Earth's radius in km
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    return R * c

all_merged_df['haversine_distance_km'] = all_merged_df.apply(
    lambda row: haversine(row['Origin_Lat'], row['Origin_Lon'], row['Dest_Lat'], row['Dest_Lon']), axis=1
)
all_merged_df['route_efficiency'] = all_merged_df['TRANSPORTATION_DISTANCE_IN_KM'] / all_merged_df['haversine_distance_km'].replace(0, 1)

# %%
# Temporal features
all_merged_df['trip_duration_hours'] = (pd.to_datetime(all_merged_df['trip_end_date']) - pd.to_datetime(all_merged_df['trip_start_date'])).dt.total_seconds() / 3600
all_merged_df['eta_deviation_hours'] = (pd.to_datetime(all_merged_df['actual_eta']) - pd.to_datetime(all_merged_df['Planned_ETA'])).dt.total_seconds() / 3600
all_merged_df['booking_month'] = pd.to_datetime(all_merged_df['BookingID_Date']).dt.month

# %%
# Transportation features
all_merged_df['vehicle_efficiency'] = all_merged_df['TRANSPORTATION_DISTANCE_IN_KM'] / all_merged_df['Minimum_kms_to_be_covered_in_a_day'].replace(0, 1)
all_merged_df['is_ontime'] = all_merged_df['ontime'].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
# Aggregated features
# all_merged_df['avg_gdp_by_region'] = all_merged_df.groupby('Origin_Region')['gdp_origin'].transform('mean')
all_merged_df['trips_per_region'] = all_merged_df.groupby('Origin_Region')['BookingID_Date'].transform('count')

# %%
print(all_merged_df.columns.to_list())
# Out:
# ['GpsProvider', 'Market/Regular ', 'BookingID_Date', 'Origin_Location', 'Destination_Location', 'Org_lat_lon', 'Des_lat_lon', 'Data_Ping_time', 'Planned_ETA', 'Current_Location', 'DestinationLocation', 'actual_eta', 'Curr_lat', 'Curr_lon', 'ontime', 'delay', 'trip_start_date', 'trip_end_date', 'TRANSPORTATION_DISTANCE_IN_KM', 'vehicleType', 'Minimum_kms_to_be_covered_in_a_day', 'customerNameCode', 'supplierNameCode', 'Material Shipped', 'Date', 'Origin_Lat', 'Origin_Lon', 'Dest_Lat', 'Dest_Lon', 'Route', 'Origin_Region', 'Destination_Region', 'Year', 'gdp_origin', 'population_origin', 'viirs_mean_origin', 'viirs_sum_origin', 'gdp_destination', 'population_destination', 'viirs_mean_destination', 'viirs_sum_destination', 'Origin_Area', 'Destination_Area', 'viirs_per_capita_origin', 'gdp_ratio', 'haversine_distance_km', 'route_efficiency', 'trip_duration_hours', 'eta_deviation_hours', 'booking_month', 'vehicle_efficiency', 'is_ontime', 'trips_per_region']

# %% [markdown]
# #### Conversion to numerical

# %%
# Select only categorical columns (dtype = object or category)
categorical_cols = all_merged_df.select_dtypes(include=['object', 'category']).columns

# Initialize label encoders dictionary
label_encoders = {}

# Encode each categorical column
for col in categorical_cols:
    le = LabelEncoder()
    all_merged_df[col] = le.fit_transform(all_merged_df[col].astype(str))
    label_encoders[col] = le

# %%
all_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5116 entries, 0 to 5717
# Data columns (total 53 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   GpsProvider                         5116 non-null   int32
#  1   Market/Regular                      5116 non-null   int32
#  2   BookingID_Date                      5116 non-null   datetime64[ns]
#  3   Origin_Location                     5116 non-null   int32
#  4   Destination_Location                5116 non-null   int32
#  5   Org_lat_lon                         5116 non-null   int32
#  6   Des_lat_lon                         5116 non-null   int32
#  7   Data_Ping_time                      5116 non-null   datetime64[ns]
#  8   Planned_ETA                         5116 non-null   int32
#  9   Current_Location                    5116 non-null   int32
#  10  DestinationLocation                 5116 non-null   int32
#  11  actual_eta                          5116 non-null   int32
#  12  Curr_lat                            5116 non-null   float64
#  13  Curr_lon                            5116 non-null   float64
#  14  ontime                              5116 non-null   int32
#  15  delay                               5116 non-null   int32
#  16  trip_start_date                     5116 non-null   int32
#  17  trip_end_date                       5116 non-null   int32
#  18  TRANSPORTATION_DISTANCE_IN_KM       5116 non-null   float64
#  19  vehicleType                         5116 non-null   int32
#  20  Minimum_kms_to_be_covered_in_a_day  5116 non-null   float64
#  21  customerNameCode                    5116 non-null   int32
#  22  supplierNameCode                    5116 non-null   int32
#  23  Material Shipped                    5116 non-null   int32
#  24  Date                                5116 non-null   int32
#  25  Origin_Lat                          5116 non-null   float64
#  26  Origin_Lon                          5116 non-null   float64
#  27  Dest_Lat                            5116 non-null   float64
#  28  Dest_Lon                            5116 non-null   float64
#  29  Route                               5116 non-null   int32
#  30  Origin_Region                       5116 non-null   int32
#  31  Destination_Region                  5116 non-null   int32
#  32  Year                                5116 non-null   Int64
#  33  gdp_origin                          5116 non-null   float64
#  34  population_origin                   5116 non-null   float64
#  35  viirs_mean_origin                   5116 non-null   float64
#  36  viirs_sum_origin                    5116 non-null   float64
#  37  gdp_destination                     5116 non-null   float64
#  38  population_destination              5116 non-null   float64
#  39  viirs_mean_destination              5116 non-null   float64
#  40  viirs_sum_destination               5116 non-null   float64
#  41  Origin_Area                         5116 non-null   int32
#  42  Destination_Area                    5116 non-null   int32
#  43  viirs_per_capita_origin             5116 non-null   float64
#  44  gdp_ratio                           5116 non-null   float64
#  45  haversine_distance_km               5116 non-null   float64
#  46  route_efficiency                    5116 non-null   float64
#  47  trip_duration_hours                 5116 non-null   float64
#  48  eta_deviation_hours                 5116 non-null   float64
#  49  booking_month                       5116 non-null   int32
#  50  vehicle_efficiency                  5116 non-null   float64
#  51  is_ontime                           5116 non-null   int64
#  52  trips_per_region                    5116 non-null   int64
# dtypes: Int64(1), datetime64[ns](2), float64(23), int32(25), int64(2)
# memory usage: 1.6 MB

# %% [markdown]
# ### Main Research Question: To what extent can truck telemetry data accurately classify economic zones in India compared to nighttime light data and GDP estimates?

# %%
# Define Features.
truck_features = [
    'TRANSPORTATION_DISTANCE_IN_KM', 'trip_duration_hours', 'route_efficiency',
    'vehicle_efficiency', 'delay', 'eta_deviation_hours', 'is_ontime', 'trips_per_region'
]

viirs_features = [
    'viirs_mean_origin', 'viirs_sum_origin', 'viirs_mean_destination', 'viirs_sum_destination'
]

# %%
# Scale Features
scaler = StandardScaler()
X_truck = scaler.fit_transform(all_merged_df[truck_features])
X_viirs = scaler.fit_transform(all_merged_df[viirs_features])

# %%
# Define Function to Evaluate K Using Silhouette Score
def get_optimal_k_by_silhouette(X, max_k=10):
    best_k = 2
    best_score = -1
    for k in range(2, max_k + 1):
        kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
        labels = kmeans.fit_predict(X)
        score = silhouette_score(X, labels)
        if score > best_score:
            best_score = score
            best_k = k
    return best_k, best_score

# %%
# Set Optimal K for Each Feature Set
optimal_k_truck, score_truck = get_optimal_k_by_silhouette(X_truck)
optimal_k_viirs, score_viirs = get_optimal_k_by_silhouette(X_viirs)

print(f"Optimal k for truck: {optimal_k_truck} (Silhouette Score = {score_truck:.2f})")
print(f"Optimal k for VIIRS: {optimal_k_viirs} (Silhouette Score = {score_viirs:.2f})")
# Out:
# Optimal k for truck: 6 (Silhouette Score = 0.41)
# Optimal k for VIIRS: 10 (Silhouette Score = 0.57)

# %%
# Apply KMeans Clustering with Optimal K
kmeans_truck = KMeans(n_clusters=optimal_k_truck, random_state=42, n_init=10)
all_merged_df['truck_zone'] = kmeans_truck.fit_predict(X_truck)

kmeans_viirs = KMeans(n_clusters=optimal_k_viirs, random_state=42, n_init=10)
all_merged_df['viirs_zone'] = kmeans_viirs.fit_predict(X_viirs)

# Compare Clustering with Jaccard Similarity
def compute_average_jaccard(labels1, labels2):
    unique_labels = set(labels1)
    avg_jaccard = []
    for label in unique_labels:
        bin1 = (labels1 == label).astype(int)
        for label2 in set(labels2):
            bin2 = (labels2 == label2).astype(int)
            score = jaccard_score(bin1, bin2)
            avg_jaccard.append(score)
    return np.mean(avg_jaccard)

jaccard_similarity = compute_average_jaccard(
    all_merged_df['truck_zone'], all_merged_df['viirs_zone']
)

print(f"\nJaccard Similarity between Truck and VIIRS clusters: {jaccard_similarity:.2f}")
# Out:
# Jaccard Similarity between Truck and VIIRS clusters: 0.04

# %%
# Compare Average GDP by Cluster
gdp_by_truck_zone = all_merged_df.groupby('truck_zone')[['gdp_origin', 'gdp_destination']].mean()
gdp_by_viirs_zone = all_merged_df.groupby('viirs_zone')[['gdp_origin', 'gdp_destination']].mean()

# %%
print("\nAverage GDP by Truck Cluster:")
gdp_by_truck_zone
# Out:
# Average GDP by Truck Cluster:
#             gdp_origin  gdp_destination
# truck_zone
# 0             8.896204         8.913673
# 1             9.021877         9.006045
# 2             8.956917         8.945792
# 3             8.767282         8.757815
# 4             8.966000         8.966000
# 5             9.011053         9.076105

# %%
print("\nAverage GDP by VIIRS Cluster:")
gdp_by_viirs_zone
# Out:
# Average GDP by VIIRS Cluster:
#             gdp_origin  gdp_destination
# viirs_zone
# 0             8.959643         8.945586
# 1             9.052878         9.040351
# 2             8.809555         8.755394
# 3             8.479748         8.473669
# 4             8.988052         8.988386
# 5             8.498500         8.486812
# 6             8.972058         8.991124
# 7             9.017937         9.010105
# 8             8.902000         8.828273
# 9             8.857910         9.146702

# %%
#  Visualize Clusters 
from sklearn.decomposition import PCA

def plot_clusters(X, labels, title):
    pca = PCA(n_components=2)
    reduced = pca.fit_transform(X)
    plt.figure(figsize=(8, 6))
    sns.scatterplot(x=reduced[:, 0], y=reduced[:, 1], hue=labels, palette="Set2", s=60)
    plt.title(title)
    plt.xlabel("PCA 1")
    plt.ylabel("PCA 2")
    plt.legend(title="Cluster")
    plt.grid(True)
    plt.show()

# %%
plot_clusters(X_truck, all_merged_df['truck_zone'], "Truck Feature Clusters")

# %%
plot_clusters(X_viirs, all_merged_df['viirs_zone'], "VIIRS Feature Clusters")

# %%
viirs_truck = all_merged_df.groupby('truck_zone')[['viirs_mean_origin', 'viirs_mean_destination']].mean()
viirs_viirs = all_merged_df.groupby('viirs_zone')[['viirs_mean_origin', 'viirs_mean_destination']].mean()

# %%
print("\nAverage VIIRS Mean by Truck Cluster:")
viirs_truck
# Out:
# Average VIIRS Mean by Truck Cluster:
#             viirs_mean_origin  viirs_mean_destination
# truck_zone
# 0                    1.787459                1.766444
# 1                    2.023505                1.780731
# 2                    1.908897                1.873203
# 3                    1.641221                1.611974
# 4                    1.933853                1.933853
# 5                    2.200373                2.227132

# %%
print("\nAverage VIIRS Mean by VIIRS Cluster:")
viirs_viirs
# Out:
# Average VIIRS Mean by VIIRS Cluster:
#             viirs_mean_origin  viirs_mean_destination
# viirs_zone
# 0                    1.824816                2.386726
# 1                    2.042742                1.967577
# 2                    3.410555                3.101513
# 3                    1.533444                1.511889
# 4                    1.340114                1.331872
# 5                    0.690268                0.711655
# 6                    2.419322                1.654080
# 7                    2.587713                2.611112
# 8                    2.397093                0.462728
# 9                    1.301548                2.821877

# %%
# Visualize GDP Distribution Across Clusters
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
sns.boxplot(x='truck_zone', y='gdp_origin', data=all_merged_df, hue='truck_zone', palette='Set2', legend=False)
plt.title('GDP (Origin) by Truck Cluster')
plt.xlabel('Truck Cluster')
plt.ylabel('GDP (Origin)')

plt.subplot(1, 2, 2)
sns.boxplot(x='viirs_zone', y='gdp_origin', data=all_merged_df, hue='viirs_zone', palette='Set2', legend=False)
plt.title('GDP (Origin) by VIIRS Cluster')
plt.xlabel('VIIRS Cluster')
plt.ylabel('GDP (Origin)')
plt.tight_layout()
plt.show()

# %% [markdown]
# **To what extent can truck telemetry data accurately classify economic zones in India compared to nighttime light data and GDP estimates?** Truck telemetry data has limited accuracy in classifying economic zones in India, forming 6 overlapping clusters (silhouette score 0.41) with a narrow GDP range (8.767–9.021) that captures logistical patterns, such as high trip frequencies in populous regions like Uttar Pradesh, rather than economic variation, as evidenced by PCA visualizations and box plots. In contrast, VIIRS nighttime light data performs significantly better, creating 10 distinct clusters (silhouette score 0.57) with a wider GDP range (8.480–9.147) and VIIRS Mean range (0.690–3.411), effectively aligning with economic hubs like Delhi (Cluster 2, high GDP and VIIRS Mean 3.411) and rural areas like Arunachal Pradesh (Cluster 5, low GDP and VIIRS Mean 0.690). The Jaccard similarity of 0.04 indicates minimal overlap between the two, confirming VIIRS’s superiority for economic zoning, while truck data is more suitable for identifying operational zones for logistics optimization, such as route planning and addressing delays in low-performing clusters (e.g., Cluster 3). Integrating both datasets could enhance regional economic analysis by combining economic and transport insights for policy and commercial applications.
#
# ### Results Summary
#
# | **Metric**                     | **Truck Features**         | **VIIRS Features**         |
# |-------------------------------|----------------------------|----------------------------|
# | **Optimal k**                 | 6                          | 10                         |
# | **Silhouette Score**          | 0.41                       | 0.57                       |
# | **GDP Range (Origin)**        | 8.767–9.021                | 8.480–9.053                |
# | **VIIRS Mean Range (Origin)** | 1.641–2.200                | 0.690–3.411                |
# | **Jaccard Similarity**        | 0.04 (between truck and VIIRS clusters) | -                          |
